# %% [markdown]
# # Clase 2 — Agente de clima real con Ollama\n\nEste notebook sirve como guía de explicación para la clase.

# %% [markdown]
# ## Objetivo\nConstruir un agente que consulte una API real de clima, pida contexto del usuario y use Ollama.

# %%
from pprint import pprint\nimport sys\nsys.path.append('../06_codigo')\nfrom tools.weather_api import get_weather_forecast\n\ndata = get_weather_forecast('medellin')\npprint(data)

# %% [markdown]
# ## Interpretación\nAquí ya estamos viendo datos reales consultados desde una API.
